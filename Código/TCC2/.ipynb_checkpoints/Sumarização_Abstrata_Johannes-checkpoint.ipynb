# %% [markdown]
# Importação das bibliotecas que serão utilizadas para a criação do algoritmo de Sumarização Abstrata

# %%
import numpy as np
import pandas as pd
import spacy
import string
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.layers import Input, LSTM, Dense
from keras.models import Model
import tensorflow_datasets as tfds
import random
from sklearn.model_selection import train_test_split
import re
# Out:
# In C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# Using TensorFlow backend.

# %%
def tokenize(lang, max_seq):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(lower=True, filters='',
                                                         num_words=2**16)
  lang_tokenizer.fit_on_texts(lang)



  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post',
                                                         maxlen=max_seq)

  return tensor, lang_tokenizer

def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %% [markdown]
# Carregado o dataset com as notícias, separando o texto e o título

# %%
data = pd.read_json('tcc1.json')

noticias = ['<start> ' + m + ' <end>' for m in data.texto.tolist()]
titulos  = ['<start> ' + m + ' <end>' for m in data.título.tolist()]

input_tensor, inp_lang = tokenize(noticias, max_seq=600)
target_tensor, targ_lang = tokenize(titulos, max_seq=20)

# %%
inp_lang.word_index['<start>']
# Out:
# 42

# %%
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
from sklearn.model_selection import train_test_split

# faz separacao 80/20
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# mostra tamanhos
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 229 229 58 58

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 42 ----> <start>
# 3 ----> o
# 76 ----> presidente
# 6 ----> do
# 1543 ----> senado,
# 3594 ----> davi
# 3054 ----> alcolumbre
# 5587 ----> (dem-ap),
# 358 ----> anunciou
# 12 ----> na
# 861 ----> manhã
# 177 ----> desta
# 66 ----> segunda-feira
# 153 ----> (18)
# 5 ----> que
# 17 ----> não
# 1570 ----> haverá
# 3055 ----> recesso
# 1692 ----> parlamentar
# 11 ----> no
# 957 ----> congresso
# 186 ----> nacional
# 11 ----> no
# 147 ----> meio
# 233 ----> deste
# 143 ----> ano
# 7 ----> em
# 1055 ----> razão
# 8 ----> da
# 60 ----> pandemia
# 6 ----> do
# 71 ----> novo
# 73 ----> coronavírus
# 27 ----> –
# 112 ----> além
# 1 ----> de
# 76 ----> presidente
# 6 ----> do
# 1543 ----> senado,
# 3054 ----> alcolumbre
# 33 ----> também
# 8357 ----> preside
# 3 ----> o
# 2579 ----> congresso,
# 5 ----> que
# 1789 ----> reúne
# 1042 ----> deputados
# 4 ----> e
# 8358 ----> senadores.
# 29 ----> à
# 3549 ----> noite,
# 3 ----> o
# 76 ----> presidente
# 8 ----> da
# 1098 ----> câmara,
# 1266 ----> rodrigo
# 4384 ----> maia,
# 2449 ----> confirmou
# 2 ----> a
# 596 ----> informação
# 4 ----> e
# 50 ----> disse
# 5 ----> que
# 3 ----> o
# 3595 ----> cancelamento
# 6 ----> do
# 3055 ----> recesso
# 1 ----> de
# 147 ----> meio
# 1 ----> de
# 143 ----> ano
# 137 ----> estava
# 8359 ----> combinado
# 10 ----> com
# 8360 ----> alcolumbre.
# 14 ----> os
# 98 ----> dois
# 1734 ----> períodos
# 1 ----> de
# 3055 ----> recesso
# 26 ----> são
# 11 ----> no
# 144 ----> final
# 6 ----> do
# 143 ----> ano
# 8361 ----> (23
# 1 ----> de
# 1043 ----> dezembro
# 2 ----> a
# 689 ----> 1º
# 1 ----> de
# 8362 ----> fevereiro)
# 4 ----> e
# 11 ----> no
# 147 ----> meio
# 6 ----> do
# 143 ----> ano
# 8363 ----> (18
# 2 ----> a
# 936 ----> 31
# 1 ----> de
# 8364 ----> julho).
# 469 ----> este
# 546 ----> último
# 21 ----> foi
# 8365 ----> cancelado.
# 7 ----> em
# 464 ----> reunião
# 1 ----> de
# 1759 ----> líderes
# 6 ----> do
# 1543 ----> senado,
# 33 ----> também
# 21 ----> foi
# 3596 ----> decidido
# 8366 ----> adiar
# 3 ----> o
# 476 ----> retorno
# 30 ----> das
# 8367 ----> sessões
# 8368 ----> presenciais,
# 5 ----> que
# 137 ----> estava
# 2580 ----> inicialmente
# 1916 ----> previsto
# 9 ----> para
# 203 ----> 15
# 1 ----> de
# 1099 ----> junho
# 27 ----> –
# 597 ----> atualmente,
# 14 ----> os
# 1294 ----> parlamentares
# 68 ----> estão
# 25 ----> se
# 5588 ----> reunindo
# 621 ----> somente
# 18 ----> por
# 3597 ----> videoconferência.
# 56 ----> entre
# 360 ----> 20
# 4 ----> e
# 279 ----> 30
# 1 ----> de
# 1450 ----> junho,
# 14 ----> os
# 4385 ----> senadores
# 2858 ----> voltarão
# 2 ----> a
# 2510 ----> analisar
# 2 ----> a
# 240 ----> situação
# 9 ----> para
# 1891 ----> decidir
# 25 ----> se
# 2858 ----> voltarão
# 2 ----> a
# 4386 ----> frequentar
# 3 ----> o
# 5589 ----> plenário
# 7 ----> em
# 1704 ----> julho
# 34 ----> ou
# 5590 ----> agosto.
# 1624 ----> pauta
# 8 ----> da
# 131 ----> semana
# 65 ----> durante
# 2 ----> a
# 464 ----> reunião
# 177 ----> desta
# 1219 ----> segunda-feira,
# 14 ----> os
# 1759 ----> líderes
# 6 ----> do
# 3598 ----> senado
# 33 ----> também
# 2577 ----> decidiram
# 423 ----> quais
# 1625 ----> projetos
# 180 ----> serão
# 1589 ----> analisados
# 47 ----> nesta
# 992 ----> semana.
# 56 ----> entre
# 304 ----> esses
# 8369 ----> projetos,
# 46 ----> está
# 13 ----> um
# 663 ----> texto
# 5 ----> que
# 4387 ----> propõe
# 3 ----> o
# 2581 ----> adiamento
# 6 ----> do
# 611 ----> enem
# 233 ----> deste
# 564 ----> ano.
# 3 ----> o
# 197 ----> projeto
# 907 ----> prevê
# 2 ----> a
# 2582 ----> prorrogação
# 5591 ----> automática
# 1 ----> de
# 1324 ----> prazos
# 9 ----> para
# 1881 ----> provas,
# 1076 ----> exames
# 4 ----> e
# 828 ----> demais
# 697 ----> atividade
# 9 ----> para
# 428 ----> acesso
# 24 ----> ao
# 580 ----> ensino
# 1100 ----> superior
# 7 ----> em
# 187 ----> caso
# 1 ----> de
# 2008 ----> reconhecimento
# 1 ----> de
# 58 ----> estado
# 1 ----> de
# 4374 ----> calamidade
# 31 ----> pelo
# 957 ----> congresso
# 3056 ----> nacional.
# 33 ----> também
# 299 ----> devem
# 528 ----> entrar
# 7 ----> em
# 1624 ----> pauta
# 11 ----> no
# 3598 ----> senado
# 47 ----> nesta
# 5592 ----> semana:
# 197 ----> projeto
# 5 ----> que
# 5 ----> que
# 8370 ----> flexibiliza
# 1626 ----> relações
# 8371 ----> jurídicas
# 1 ----> de
# 331 ----> direito
# 3599 ----> privado
# 65 ----> durante
# 2 ----> a
# 8372 ----> pandemia;medida
# 1549 ----> provisória
# 5 ----> que
# 8373 ----> dispõe
# 55 ----> sobre
# 561 ----> regras
# 9 ----> para
# 1267 ----> vendas
# 1 ----> de
# 5593 ----> imóveis
# 8 ----> da
# 8374 ----> união;proposta
# 5 ----> que
# 8375 ----> destina
# 245 ----> leitos
# 1 ----> de
# 378 ----> hospitais
# 2941 ----> privados
# 9 ----> para
# 3 ----> o
# 8376 ----> sus;proposta
# 5 ----> que
# 1627 ----> inclui
# 12 ----> na
# 1935 ----> cobertura
# 22 ----> dos
# 8377 ----> seguros
# 1 ----> de
# 310 ----> vida
# 339 ----> óbitos
# 18 ----> por
# 8378 ----> covid;projeto
# 5 ----> que
# 3359 ----> autoriza
# 2582 ----> prorrogação
# 1 ----> de
# 5594 ----> dívidas
# 8379 ----> rurais
# 7 ----> em
# 2266 ----> decorrência
# 8 ----> da
# 60 ----> pandemia
# 6 ----> do
# 73 ----> coronavírus
# 8380 ----> (covid-19);texto
# 5 ----> que
# 907 ----> prevê
# 3 ----> o
# 929 ----> emprego
# 8 ----> da
# 8381 ----> telemedicina
# 8382 ----> veterinária
# 65 ----> durante
# 2 ----> a
# 60 ----> pandemia
# 1 ----> de
# 133 ----> coronavírus.
# 43 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 276 ----> recesso
# 277 ----> parlamentar
# 20 ----> é
# 520 ----> cancelado
# 4 ----> em
# 109 ----> meio
# 29 ----> à
# 24 ----> pandemia
# 2 ----> <end>

# %%
# criando o dataset

BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 16
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 200
units = 1024

vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([16, 600]), TensorShape([16, 20]))

# %%
# bloco do encoder

class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (16, 600, 1024)
# Encoder Hidden state shape: (batch size, units) (16, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (16, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (16, 600, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (16, 1612)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
import os

checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
import time

EPOCHS = 200

loss_acumulado = []

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  loss_acumulado.append(total_loss / steps_per_epoch)
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))

checkpoint.save(file_prefix = checkpoint_prefix)
# Out:
# Epoch 1 Batch 0 Loss 5.4466
# Epoch 1 Loss 4.9081
# Time taken for 1 epoch 27.95228338241577 sec
#
# Epoch 2 Batch 0 Loss 4.5856
# Epoch 2 Loss 4.4275
# Time taken for 1 epoch 7.6473963260650635 sec
#
# Epoch 3 Batch 0 Loss 4.3685
# Epoch 3 Loss 4.3010
# Time taken for 1 epoch 7.760169744491577 sec
#
# Epoch 4 Batch 0 Loss 4.1508
# Epoch 4 Loss 4.2086
# Time taken for 1 epoch 7.797110319137573 sec
#
# Epoch 5 Batch 0 Loss 3.9965
# Epoch 5 Loss 4.0943
# Time taken for 1 epoch 7.904170036315918 sec
#
# Epoch 6 Batch 0 Loss 3.9618
# Epoch 6 Loss 3.9483
# Time taken for 1 epoch 7.925021648406982 sec
#
# Epoch 7 Batch 0 Loss 3.9770
# Epoch 7 Loss 3.7799
# Time taken for 1 epoch 8.00286340713501 sec
#
# Epoch 8 Batch 0 Loss 3.7371
# Epoch 8 Loss 3.5799
# Time taken for 1 epoch 8.070432901382446 sec
#
# Epoch 9 Batch 0 Loss 3.4836
# Epoch 9 Loss 3.3759
# Time taken for 1 epoch 8.093168258666992 sec
#
# Epoch 10 Batch 0 Loss 3.0933
# Epoch 10 Loss 3.1237
# Time taken for 1 epoch 8.191323518753052 sec
#
# Epoch 11 Batch 0 Loss 2.9675
# Epoch 11 Loss 2.8608
# Time taken for 1 epoch 8.241986989974976 sec
#
# Epoch 12 Batch 0 Loss 2.8411
# Epoch 12 Loss 2.6108
# Time taken for 1 epoch 8.288495779037476 sec
#
# Epoch 13 Batch 0 Loss 2.3705
# Epoch 13 Loss 2.3842
# Time taken for 1 epoch 8.304370403289795 sec
#
# Epoch 14 Batch 0 Loss 2.0945
# Epoch 14 Loss 2.1380
# Time taken for 1 epoch 8.307333946228027 sec
#
# Epoch 15 Batch 0 Loss 2.0472
# Epoch 15 Loss 1.9666
# Time taken for 1 epoch 8.258514165878296 sec
#
# Epoch 16 Batch 0 Loss 1.6840
# Epoch 16 Loss 1.7749
# Time taken for 1 epoch 8.234727144241333 sec
#
# Epoch 17 Batch 0 Loss 1.4218
# Epoch 17 Loss 1.5506
# Time taken for 1 epoch 8.208062887191772 sec
#
# Epoch 18 Batch 0 Loss 1.3015
# Epoch 18 Loss 1.3597
# Time taken for 1 epoch 8.189393758773804 sec
#
# Epoch 19 Batch 0 Loss 1.0322
# Epoch 19 Loss 1.1736
# Time taken for 1 epoch 8.176352739334106 sec
#
# Epoch 20 Batch 0 Loss 1.0269
# Epoch 20 Loss 1.0194
# Time taken for 1 epoch 8.192629337310791 sec
#
# Epoch 21 Batch 0 Loss 0.8666
# Epoch 21 Loss 0.8757
# Time taken for 1 epoch 8.218024969100952 sec
#
# Epoch 22 Batch 0 Loss 0.7465
# Epoch 22 Loss 0.7626
# Time taken for 1 epoch 8.193018436431885 sec
#
# Epoch 23 Batch 0 Loss 0.5701
# Epoch 23 Loss 0.6704
# Time taken for 1 epoch 8.23574709892273 sec
#
# Epoch 24 Batch 0 Loss 0.5629
# Epoch 24 Loss 0.5902
# Time taken for 1 epoch 8.245295524597168 sec
#
# Epoch 25 Batch 0 Loss 0.3869
# Epoch 25 Loss 0.5047
# Time taken for 1 epoch 8.24674916267395 sec
#
# Epoch 26 Batch 0 Loss 0.3163
# Epoch 26 Loss 0.4347
# Time taken for 1 epoch 8.203527212142944 sec
#
# Epoch 27 Batch 0 Loss 0.3141
# Epoch 27 Loss 0.3965
# Time taken for 1 epoch 8.219038486480713 sec
#
# Epoch 28 Batch 0 Loss 0.2635
# Epoch 28 Loss 0.3499
# Time taken for 1 epoch 8.222957372665405 sec
#
# Epoch 29 Batch 0 Loss 0.2892
# Epoch 29 Loss 0.2956
# Time taken for 1 epoch 8.20513916015625 sec
#
# Epoch 30 Batch 0 Loss 0.2039
# Epoch 30 Loss 0.2615
# Time taken for 1 epoch 8.179673194885254 sec
#
# Epoch 31 Batch 0 Loss 0.1835
# Epoch 31 Loss 0.2285
# Time taken for 1 epoch 8.20486068725586 sec
#
# Epoch 32 Batch 0 Loss 0.1777
# Epoch 32 Loss 0.2133
# Time taken for 1 epoch 8.22116470336914 sec
#
# Epoch 33 Batch 0 Loss 0.1151
# Epoch 33 Loss 0.1999
# Time taken for 1 epoch 8.193733215332031 sec
#
# Epoch 34 Batch 0 Loss 0.1112
# Epoch 34 Loss 0.1813
# Time taken for 1 epoch 8.223833560943604 sec
#
# Epoch 35 Batch 0 Loss 0.1210
# Epoch 35 Loss 0.1743
# Time taken for 1 epoch 8.190603971481323 sec
#
# Epoch 36 Batch 0 Loss 0.0978
# Epoch 36 Loss 0.1517
# Time taken for 1 epoch 8.206023216247559 sec
#
# Epoch 37 Batch 0 Loss 0.1443
# Epoch 37 Loss 0.1610
# Time taken for 1 epoch 8.253340244293213 sec
#
# Epoch 38 Batch 0 Loss 0.1322
# Epoch 38 Loss 0.1482
# Time taken for 1 epoch 8.205764770507812 sec
#
# Epoch 39 Batch 0 Loss 0.1054
# Epoch 39 Loss 0.1372
# Time taken for 1 epoch 8.226017236709595 sec
#
# Epoch 40 Batch 0 Loss 0.0711
# Epoch 40 Loss 0.1175
# Time taken for 1 epoch 8.196756362915039 sec
#
# Epoch 41 Batch 0 Loss 0.0612
# Epoch 41 Loss 0.1094
# Time taken for 1 epoch 8.16356897354126 sec
#
# Epoch 42 Batch 0 Loss 0.0513
# Epoch 42 Loss 0.1009
# Time taken for 1 epoch 8.214918375015259 sec
#
# Epoch 43 Batch 0 Loss 0.0462
# Epoch 43 Loss 0.0864
# Time taken for 1 epoch 8.197428464889526 sec
#
# Epoch 44 Batch 0 Loss 0.0828
# Epoch 44 Loss 0.0827
# Time taken for 1 epoch 8.174684524536133 sec
#
# Epoch 45 Batch 0 Loss 0.0337
# Epoch 45 Loss 0.0740
# Time taken for 1 epoch 8.181563377380371 sec
#
# Epoch 46 Batch 0 Loss 0.0693
# Epoch 46 Loss 0.0676
# Time taken for 1 epoch 8.155782222747803 sec
#
# Epoch 47 Batch 0 Loss 0.0597
# Epoch 47 Loss 0.0649
# Time taken for 1 epoch 8.194692850112915 sec
#
# Epoch 48 Batch 0 Loss 0.0469
# Epoch 48 Loss 0.0583
# Time taken for 1 epoch 8.186447620391846 sec
#
# Epoch 49 Batch 0 Loss 0.0430
# Epoch 49 Loss 0.0612
# Time taken for 1 epoch 8.212965965270996 sec
#
# Epoch 50 Batch 0 Loss 0.0279
# Epoch 50 Loss 0.0492
# Time taken for 1 epoch 8.16086459159851 sec
#
# Epoch 51 Batch 0 Loss 0.0420
# Epoch 51 Loss 0.0489
# Time taken for 1 epoch 8.196952104568481 sec
#
# Epoch 52 Batch 0 Loss 0.0295
# Epoch 52 Loss 0.0443
# Time taken for 1 epoch 8.202210903167725 sec
#
# Epoch 53 Batch 0 Loss 0.0201
# Epoch 53 Loss 0.0433
# Time taken for 1 epoch 8.160205125808716 sec
#
# Epoch 54 Batch 0 Loss 0.0350
# Epoch 54 Loss 0.0453
# Time taken for 1 epoch 8.187971830368042 sec
#
# Epoch 55 Batch 0 Loss 0.0324
# Epoch 55 Loss 0.0403
# Time taken for 1 epoch 8.232611894607544 sec
#
# Epoch 56 Batch 0 Loss 0.0389
# Epoch 56 Loss 0.0398
# Time taken for 1 epoch 8.234761714935303 sec
#
# Epoch 57 Batch 0 Loss 0.0335
# Epoch 57 Loss 0.0328
# Time taken for 1 epoch 8.206022500991821 sec
#
# Epoch 58 Batch 0 Loss 0.0197
# Epoch 58 Loss 0.0335
# Time taken for 1 epoch 8.179178953170776 sec
#
# Epoch 59 Batch 0 Loss 0.0187
# Epoch 59 Loss 0.0328
# Time taken for 1 epoch 8.205260753631592 sec
#
# Epoch 60 Batch 0 Loss 0.0322
# Epoch 60 Loss 0.0313
# Time taken for 1 epoch 8.164815425872803 sec
#
# Epoch 61 Batch 0 Loss 0.0137
# Epoch 61 Loss 0.0306
# Time taken for 1 epoch 8.182384729385376 sec
#
# Epoch 62 Batch 0 Loss 0.0224
# Epoch 62 Loss 0.0314
# Time taken for 1 epoch 8.227643966674805 sec
#
# Epoch 63 Batch 0 Loss 0.0194
# Epoch 63 Loss 0.0291
# Time taken for 1 epoch 8.203901529312134 sec
#
# Epoch 64 Batch 0 Loss 0.0153
# Epoch 64 Loss 0.0314
# Time taken for 1 epoch 8.173471689224243 sec
#
# Epoch 65 Batch 0 Loss 0.0217
# Epoch 65 Loss 0.0338
# Time taken for 1 epoch 8.20311164855957 sec
#
# Epoch 66 Batch 0 Loss 0.0090
# Epoch 66 Loss 0.0309
# Time taken for 1 epoch 8.176878690719604 sec
#
# Epoch 67 Batch 0 Loss 0.0464
# Epoch 67 Loss 0.0315
# Time taken for 1 epoch 8.20609164237976 sec
#
# Epoch 68 Batch 0 Loss 0.0157
# Epoch 68 Loss 0.0357
# Time taken for 1 epoch 8.241657972335815 sec
#
# Epoch 69 Batch 0 Loss 0.0191
# Epoch 69 Loss 0.0498
# Time taken for 1 epoch 8.2235426902771 sec
#
# Epoch 70 Batch 0 Loss 0.0695
# Epoch 70 Loss 0.0588
# Time taken for 1 epoch 8.197234153747559 sec
#
# Epoch 71 Batch 0 Loss 0.0555
# Epoch 71 Loss 0.0826
# Time taken for 1 epoch 8.201075553894043 sec
#
# Epoch 72 Batch 0 Loss 0.1325
# Epoch 72 Loss 0.1175
# Time taken for 1 epoch 8.163950681686401 sec
#
# Epoch 73 Batch 0 Loss 0.0633
# Epoch 73 Loss 0.1743
# Time taken for 1 epoch 8.185366153717041 sec
#
# Epoch 74 Batch 0 Loss 0.1261
# Epoch 74 Loss 0.2152
# Time taken for 1 epoch 8.150740146636963 sec
#
# Epoch 75 Batch 0 Loss 0.1744
# Epoch 75 Loss 0.2036
# Time taken for 1 epoch 8.235365390777588 sec
#
# Epoch 76 Batch 0 Loss 0.1378
# Epoch 76 Loss 0.1771
# Time taken for 1 epoch 8.149146795272827 sec
#
# Epoch 77 Batch 0 Loss 0.0747
# Epoch 77 Loss 0.1226
# Time taken for 1 epoch 8.155167579650879 sec
#
# Epoch 78 Batch 0 Loss 0.0554
# Epoch 78 Loss 0.0801
# Time taken for 1 epoch 8.143856287002563 sec
#
# Epoch 79 Batch 0 Loss 0.0407
# Epoch 79 Loss 0.0604
# Time taken for 1 epoch 8.1604905128479 sec
#
# Epoch 80 Batch 0 Loss 0.0282
# Epoch 80 Loss 0.0493
# Time taken for 1 epoch 8.16411828994751 sec
#
# Epoch 81 Batch 0 Loss 0.0418
# Epoch 81 Loss 0.0415
# Time taken for 1 epoch 8.175150156021118 sec
#
# Epoch 82 Batch 0 Loss 0.0120
# Epoch 82 Loss 0.0322
# Time taken for 1 epoch 8.194267749786377 sec
#
# Epoch 83 Batch 0 Loss 0.0251
# Epoch 83 Loss 0.0319
# Time taken for 1 epoch 8.21758222579956 sec
#
# Epoch 84 Batch 0 Loss 0.0332
# Epoch 84 Loss 0.0289
# Time taken for 1 epoch 8.187313795089722 sec
#
# Epoch 85 Batch 0 Loss 0.0370
# Epoch 85 Loss 0.0299
# Time taken for 1 epoch 8.15359091758728 sec
#
# Epoch 86 Batch 0 Loss 0.0252
# Epoch 86 Loss 0.0228
# Time taken for 1 epoch 8.177708148956299 sec
#
# Epoch 87 Batch 0 Loss 0.0323
# Epoch 87 Loss 0.0273
# Time taken for 1 epoch 8.186341524124146 sec
#
# Epoch 88 Batch 0 Loss 0.0367
# Epoch 88 Loss 0.0326
# Time taken for 1 epoch 8.205616474151611 sec
#
# Epoch 89 Batch 0 Loss 0.0113
# Epoch 89 Loss 0.0274
# Time taken for 1 epoch 8.169580459594727 sec
#
# Epoch 90 Batch 0 Loss 0.0316
# Epoch 90 Loss 0.0242
# Time taken for 1 epoch 8.177283763885498 sec
#
# Epoch 91 Batch 0 Loss 0.0289
# Epoch 91 Loss 0.0234
# Time taken for 1 epoch 8.172227144241333 sec
#
# Epoch 92 Batch 0 Loss 0.0153
# Epoch 92 Loss 0.0209
# Time taken for 1 epoch 8.147622346878052 sec
#
# Epoch 93 Batch 0 Loss 0.0035
# Epoch 93 Loss 0.0225
# Time taken for 1 epoch 8.175142288208008 sec
#
# Epoch 94 Batch 0 Loss 0.0516
# Epoch 94 Loss 0.0259
# Time taken for 1 epoch 8.197757720947266 sec
#
# Epoch 95 Batch 0 Loss 0.0116
# Epoch 95 Loss 0.0217
# Time taken for 1 epoch 8.17681360244751 sec
#
# Epoch 96 Batch 0 Loss 0.0183
# Epoch 96 Loss 0.0200
# Time taken for 1 epoch 8.18245530128479 sec
#
# Epoch 97 Batch 0 Loss 0.0078
# Epoch 97 Loss 0.0201
# Time taken for 1 epoch 8.123524188995361 sec
#
# Epoch 98 Batch 0 Loss 0.0127
# Epoch 98 Loss 0.0237
# Time taken for 1 epoch 8.18177604675293 sec
#
# Epoch 99 Batch 0 Loss 0.0094
# Epoch 99 Loss 0.0202
# Time taken for 1 epoch 8.175415515899658 sec
#
# Epoch 100 Batch 0 Loss 0.0190
# Epoch 100 Loss 0.0233
# Time taken for 1 epoch 8.172613859176636 sec
#
# Epoch 101 Batch 0 Loss 0.0049
# Epoch 101 Loss 0.0222
# Time taken for 1 epoch 8.191508769989014 sec
#
# Epoch 102 Batch 0 Loss 0.0104
# Epoch 102 Loss 0.0194
# Time taken for 1 epoch 8.19915771484375 sec
#
# Epoch 103 Batch 0 Loss 0.0107
# Epoch 103 Loss 0.0210
# Time taken for 1 epoch 8.192519903182983 sec
#
# Epoch 104 Batch 0 Loss 0.0228
# Epoch 104 Loss 0.0212
# Time taken for 1 epoch 8.15526008605957 sec
#
# Epoch 105 Batch 0 Loss 0.0059
# Epoch 105 Loss 0.0225
# Time taken for 1 epoch 8.211949110031128 sec
#
# Epoch 106 Batch 0 Loss 0.0109
# Epoch 106 Loss 0.0211
# Time taken for 1 epoch 8.208457469940186 sec
#
# Epoch 107 Batch 0 Loss 0.0244
# Epoch 107 Loss 0.0247
# Time taken for 1 epoch 8.198023557662964 sec
#
# Epoch 108 Batch 0 Loss 0.0241
# Epoch 108 Loss 0.0238
# Time taken for 1 epoch 8.17134428024292 sec
#
# Epoch 109 Batch 0 Loss 0.0292
# Epoch 109 Loss 0.0193
# Time taken for 1 epoch 8.19721245765686 sec
#
# Epoch 110 Batch 0 Loss 0.0051
# Epoch 110 Loss 0.0215
# Time taken for 1 epoch 8.178705215454102 sec
#
# Epoch 111 Batch 0 Loss 0.0150
# Epoch 111 Loss 0.0179
# Time taken for 1 epoch 8.192806482315063 sec
#
# Epoch 112 Batch 0 Loss 0.0028
# Epoch 112 Loss 0.0158
# Time taken for 1 epoch 8.213598728179932 sec
#
# Epoch 113 Batch 0 Loss 0.0112
# Epoch 113 Loss 0.0211
# Time taken for 1 epoch 8.17179250717163 sec
#
# Epoch 114 Batch 0 Loss 0.0165
# Epoch 114 Loss 0.0200
# Time taken for 1 epoch 8.194201707839966 sec
#
# Epoch 115 Batch 0 Loss 0.0074
# Epoch 115 Loss 0.0206
# Time taken for 1 epoch 8.195488452911377 sec
#
# Epoch 116 Batch 0 Loss 0.0207
# Epoch 116 Loss 0.0181
# Time taken for 1 epoch 8.204056739807129 sec
#
# Epoch 117 Batch 0 Loss 0.0225
# Epoch 117 Loss 0.0197
# Time taken for 1 epoch 8.206241607666016 sec
#
# Epoch 118 Batch 0 Loss 0.0197
# Epoch 118 Loss 0.0202
# Time taken for 1 epoch 8.208424091339111 sec
#
# Epoch 119 Batch 0 Loss 0.0237
# Epoch 119 Loss 0.0202
# Time taken for 1 epoch 8.16991662979126 sec
#
# Epoch 120 Batch 0 Loss 0.0055
# Epoch 120 Loss 0.0173
# Time taken for 1 epoch 8.183654069900513 sec
#
# Epoch 121 Batch 0 Loss 0.0081
# Epoch 121 Loss 0.0170
# Time taken for 1 epoch 8.187906980514526 sec
#
# Epoch 122 Batch 0 Loss 0.0240
# Epoch 122 Loss 0.0179
# Time taken for 1 epoch 8.169463634490967 sec
#
# Epoch 123 Batch 0 Loss 0.0262
# Epoch 123 Loss 0.0157
# Time taken for 1 epoch 8.216301202774048 sec
#
# Epoch 124 Batch 0 Loss 0.0186
# Epoch 124 Loss 0.0213
# Time taken for 1 epoch 8.186518430709839 sec
#
# Epoch 125 Batch 0 Loss 0.0284
# Epoch 125 Loss 0.0194
# Time taken for 1 epoch 8.213179349899292 sec
#
# Epoch 126 Batch 0 Loss 0.0096
# Epoch 126 Loss 0.0188
# Time taken for 1 epoch 8.176837921142578 sec
#
# Epoch 127 Batch 0 Loss 0.0156
# Epoch 127 Loss 0.0173
# Time taken for 1 epoch 8.203342199325562 sec
#
# Epoch 128 Batch 0 Loss 0.0026
# Epoch 128 Loss 0.0163
# Time taken for 1 epoch 8.20224404335022 sec
#
# Epoch 129 Batch 0 Loss 0.0190
# Epoch 129 Loss 0.0167
# Time taken for 1 epoch 8.165553569793701 sec
#
# Epoch 130 Batch 0 Loss 0.0131
# Epoch 130 Loss 0.0174
# Time taken for 1 epoch 8.202991485595703 sec
#
# Epoch 131 Batch 0 Loss 0.0141
# Epoch 131 Loss 0.0183
# Time taken for 1 epoch 8.193422555923462 sec
#
# Epoch 132 Batch 0 Loss 0.0091
# Epoch 132 Loss 0.0168
# Time taken for 1 epoch 8.176788568496704 sec
#
# Epoch 133 Batch 0 Loss 0.0028
# Epoch 133 Loss 0.0177
# Time taken for 1 epoch 8.163499116897583 sec
#
# Epoch 134 Batch 0 Loss 0.0076
# Epoch 134 Loss 0.0168
# Time taken for 1 epoch 8.207493305206299 sec
#
# Epoch 135 Batch 0 Loss 0.0012
# Epoch 135 Loss 0.0166
# Time taken for 1 epoch 8.194581747055054 sec
#
# Epoch 136 Batch 0 Loss 0.0037
# Epoch 136 Loss 0.0166
# Time taken for 1 epoch 8.161796808242798 sec
#
# Epoch 137 Batch 0 Loss 0.0236
# Epoch 137 Loss 0.0153
# Time taken for 1 epoch 8.183940172195435 sec
#
# Epoch 138 Batch 0 Loss 0.0023
# Epoch 138 Loss 0.0178
# Time taken for 1 epoch 8.1818687915802 sec
#
# Epoch 139 Batch 0 Loss 0.0076
# Epoch 139 Loss 0.0205
# Time taken for 1 epoch 8.181060075759888 sec
#
# Epoch 140 Batch 0 Loss 0.0805
# Epoch 140 Loss 0.0395
# Time taken for 1 epoch 8.209719181060791 sec
#
# Epoch 141 Batch 0 Loss 0.0562
# Epoch 141 Loss 0.0503
# Time taken for 1 epoch 8.160725831985474 sec
#
# Epoch 142 Batch 0 Loss 0.0587
# Epoch 142 Loss 0.0788
# Time taken for 1 epoch 8.173155546188354 sec
#
# Epoch 143 Batch 0 Loss 0.0527
# Epoch 143 Loss 0.0981
# Time taken for 1 epoch 8.148419618606567 sec
#
# Epoch 144 Batch 0 Loss 0.1585
# Epoch 144 Loss 0.1709
# Time taken for 1 epoch 8.116339445114136 sec
#
# Epoch 145 Batch 0 Loss 0.2466
# Epoch 145 Loss 0.2177
# Time taken for 1 epoch 8.185104131698608 sec
#
# Epoch 146 Batch 0 Loss 0.1369
# Epoch 146 Loss 0.2545
# Time taken for 1 epoch 8.19090986251831 sec
#
# Epoch 147 Batch 0 Loss 0.1221
# Epoch 147 Loss 0.2278
# Time taken for 1 epoch 8.178058862686157 sec
#
# Epoch 148 Batch 0 Loss 0.0985
# Epoch 148 Loss 0.1496
# Time taken for 1 epoch 8.160716772079468 sec
#
# Epoch 149 Batch 0 Loss 0.0698
# Epoch 149 Loss 0.0983
# Time taken for 1 epoch 8.147786140441895 sec
#
# Epoch 150 Batch 0 Loss 0.0222
# Epoch 150 Loss 0.0730
# Time taken for 1 epoch 8.117481470108032 sec
#
# Epoch 151 Batch 0 Loss 0.0379
# Epoch 151 Loss 0.0611
# Time taken for 1 epoch 8.17390513420105 sec
#
# Epoch 152 Batch 0 Loss 0.0357
# Epoch 152 Loss 0.0439
# Time taken for 1 epoch 8.152293920516968 sec
#
# Epoch 153 Batch 0 Loss 0.0641
# Epoch 153 Loss 0.0371
# Time taken for 1 epoch 8.147863864898682 sec
#
# Epoch 154 Batch 0 Loss 0.0053
# Epoch 154 Loss 0.0340
# Time taken for 1 epoch 8.19357943534851 sec
#
# Epoch 155 Batch 0 Loss 0.0062
# Epoch 155 Loss 0.0283
# Time taken for 1 epoch 8.179909467697144 sec
#
# Epoch 156 Batch 0 Loss 0.0133
# Epoch 156 Loss 0.0252
# Time taken for 1 epoch 8.170225143432617 sec
#
# Epoch 157 Batch 0 Loss 0.0258
# Epoch 157 Loss 0.0323
# Time taken for 1 epoch 8.170167446136475 sec
#
# Epoch 158 Batch 0 Loss 0.0033
# Epoch 158 Loss 0.0243
# Time taken for 1 epoch 8.164822816848755 sec
#
# Epoch 159 Batch 0 Loss 0.0069
# Epoch 159 Loss 0.0235
# Time taken for 1 epoch 8.144046068191528 sec
#
# Epoch 160 Batch 0 Loss 0.0092
# Epoch 160 Loss 0.0255
# Time taken for 1 epoch 8.140737771987915 sec
#
# Epoch 161 Batch 0 Loss 0.0042
# Epoch 161 Loss 0.0212
# Time taken for 1 epoch 8.189998865127563 sec
#
# Epoch 162 Batch 0 Loss 0.0080
# Epoch 162 Loss 0.0225
# Time taken for 1 epoch 8.179082155227661 sec
#
# Epoch 163 Batch 0 Loss 0.0167
# Epoch 163 Loss 0.0216
# Time taken for 1 epoch 8.16121244430542 sec
#
# Epoch 164 Batch 0 Loss 0.0063
# Epoch 164 Loss 0.0205
# Time taken for 1 epoch 8.151047706604004 sec
#
# Epoch 165 Batch 0 Loss 0.0271
# Epoch 165 Loss 0.0207
# Time taken for 1 epoch 8.212898969650269 sec
#
# Epoch 166 Batch 0 Loss 0.0116
# Epoch 166 Loss 0.0197
# Time taken for 1 epoch 8.175423622131348 sec
#
# Epoch 167 Batch 0 Loss 0.0070
# Epoch 167 Loss 0.0186
# Time taken for 1 epoch 8.217468976974487 sec
#
# Epoch 168 Batch 0 Loss 0.0241
# Epoch 168 Loss 0.0186
# Time taken for 1 epoch 8.14428448677063 sec
#
# Epoch 169 Batch 0 Loss 0.0113
# Epoch 169 Loss 0.0174
# Time taken for 1 epoch 8.203402519226074 sec
#
# Epoch 170 Batch 0 Loss 0.0129
# Epoch 170 Loss 0.0184
# Time taken for 1 epoch 8.18143081665039 sec
#
# Epoch 171 Batch 0 Loss 0.0119
# Epoch 171 Loss 0.0163
# Time taken for 1 epoch 8.128057718276978 sec
#
# Epoch 172 Batch 0 Loss 0.0086
# Epoch 172 Loss 0.0178
# Time taken for 1 epoch 8.136995077133179 sec
#
# Epoch 173 Batch 0 Loss 0.0138
# Epoch 173 Loss 0.0199
# Time taken for 1 epoch 8.156928062438965 sec
#
# Epoch 174 Batch 0 Loss 0.0107
# Epoch 174 Loss 0.0156
# Time taken for 1 epoch 8.127428770065308 sec
#
# Epoch 175 Batch 0 Loss 0.0102
# Epoch 175 Loss 0.0205
# Time taken for 1 epoch 8.135793924331665 sec
#
# Epoch 176 Batch 0 Loss 0.0114
# Epoch 176 Loss 0.0171
# Time taken for 1 epoch 8.147789716720581 sec
#
# Epoch 177 Batch 0 Loss 0.0273
# Epoch 177 Loss 0.0230
# Time taken for 1 epoch 8.133248567581177 sec
#
# Epoch 178 Batch 0 Loss 0.0077
# Epoch 178 Loss 0.0178
# Time taken for 1 epoch 8.161582946777344 sec
#
# Epoch 179 Batch 0 Loss 0.0176
# Epoch 179 Loss 0.0200
# Time taken for 1 epoch 8.173449993133545 sec
#
# Epoch 180 Batch 0 Loss 0.0013
# Epoch 180 Loss 0.0184
# Time taken for 1 epoch 8.167099475860596 sec
#
# Epoch 181 Batch 0 Loss 0.0033
# Epoch 181 Loss 0.0174
# Time taken for 1 epoch 8.141384363174438 sec
#
# Epoch 182 Batch 0 Loss 0.0084
# Epoch 182 Loss 0.0163
# Time taken for 1 epoch 8.18668818473816 sec
#
# Epoch 183 Batch 0 Loss 0.0136
# Epoch 183 Loss 0.0157
# Time taken for 1 epoch 8.163120746612549 sec
#
# Epoch 184 Batch 0 Loss 0.0189
# Epoch 184 Loss 0.0166
# Time taken for 1 epoch 8.177709341049194 sec
#
# Epoch 185 Batch 0 Loss 0.0217
# Epoch 185 Loss 0.0188
# Time taken for 1 epoch 8.180408239364624 sec
#
# Epoch 186 Batch 0 Loss 0.0067
# Epoch 186 Loss 0.0153
# Time taken for 1 epoch 8.174562454223633 sec
#
# Epoch 187 Batch 0 Loss 0.0033
# Epoch 187 Loss 0.0149
# Time taken for 1 epoch 8.128369569778442 sec
#
# Epoch 188 Batch 0 Loss 0.0127
# Epoch 188 Loss 0.0157
# Time taken for 1 epoch 8.167301416397095 sec
#
# Epoch 189 Batch 0 Loss 0.0212
# Epoch 189 Loss 0.0151
# Time taken for 1 epoch 8.150282859802246 sec
#
# Epoch 190 Batch 0 Loss 0.0123
# Epoch 190 Loss 0.0168
# Time taken for 1 epoch 8.19472050666809 sec
#
# Epoch 191 Batch 0 Loss 0.0329
# Epoch 191 Loss 0.0163
# Time taken for 1 epoch 8.171521186828613 sec
#
# Epoch 192 Batch 0 Loss 0.0195
# Epoch 192 Loss 0.0171
# Time taken for 1 epoch 8.18629240989685 sec
#
# Epoch 193 Batch 0 Loss 0.0201
# Epoch 193 Loss 0.0182
# Time taken for 1 epoch 8.161335945129395 sec
#
# Epoch 194 Batch 0 Loss 0.0078
# Epoch 194 Loss 0.0152
# Time taken for 1 epoch 8.16496467590332 sec
#
# Epoch 195 Batch 0 Loss 0.0164
# Epoch 195 Loss 0.0168
# Time taken for 1 epoch 8.19479751586914 sec
#
# Epoch 196 Batch 0 Loss 0.0101
# Epoch 196 Loss 0.0157
# Time taken for 1 epoch 8.163711309432983 sec
#
# Epoch 197 Batch 0 Loss 0.0121
# Epoch 197 Loss 0.0160
# Time taken for 1 epoch 8.131706714630127 sec
#
# Epoch 198 Batch 0 Loss 0.0058
# Epoch 198 Loss 0.0167
# Time taken for 1 epoch 8.11004376411438 sec
#
# Epoch 199 Batch 0 Loss 0.0184
# Epoch 199 Loss 0.0174
# Time taken for 1 epoch 8.1959388256073 sec
#
# Epoch 200 Batch 0 Loss 0.0047
# Epoch 200 Loss 0.0149
# Time taken for 1 epoch 8.18270754814148 sec
# './training_checkpoints/ckpt-1'

# %%
plt.plot(loss_acumulado)

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = sentence.lower()

  inputs = inp_lang.texts_to_sequences([sentence])

  #inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]

  print(inputs)

  inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                         maxlen=max_length_inp,
                                                         padding='post')
  print(inputs.shape)
  inputs = tf.convert_to_tensor(inputs)
  print(inputs.shape)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()


def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

mensagem = '<start> ' + data.texto.tolist()[15] + ' <end>'
print(mensagem)

translate(mensagem)
# Out:
# <start>  Escutas telefônicas da operação que prendeu membros da Secretaria da Saúde mostram um homem que segundo o MP é integrante do esquema criminoso citando o governador do Rio. Quem menciona Wilson Witzel é o operador financeiro de Mário Peixoto, Luiz Roberto Martins. O governador nega que cometeu qualquer ilegalidade. Lava Jato prende ex-deputado Paulo Melo e empresário Mário Peixoto O operador diz a um interlocutor que o empresário negociou a liberação de uma organização social (OS) com o governador. A organização social Instituto Unir Saúde fechou vários contratos com a secretaria de saúde entre os anos de 2018 e 2019 até ser desqualificada como OS pelo estado em outubro de 2019.  Segundo as investigações da Operação Favorito, a OS movimentou mais de R$ 180 milhões em contratos de gestões de Upas na Baixada. Ainda de acordo com a Polícia Federal e o Ministério Público Federal, o empresário Mário Peixoto e seu operador financeiro Luiz Roberto Martins, ambos presos na semana passada, são os verdadeiros donos da OS e efetivamente promoveram negociação espúria com funcionários públicos estaduais. Supostas citações a Witzel em investigação que prendeu Mário Peixoto são enviadas à PGR Em ligação telefônica interceptada com autorização da Justiça no dia 20 de março deste ano, Luiz Roberto Martins anuncia a uma outra pessoa reclassificação da Unir. Segundo o operador financeiro de Mário Peixoto, o empresário teria acertado diretamente com o governador e que ele estaria comprando essa reclassificação de uma outra pessoa.  "Diz o Mário que foi ele que acertou junto com o governador. Mas não publicou ainda. Eu estava comprando isso de um outro cara", disse o operador para uma outra pessoa durante uma ligação.  Na conversa, Luiz Roberto Martins chegou a mostrar seu entusiasmo com o retorno da Unir para administração das Upas na Baixada.  "As quatro de Nova Iguaçu não têm segundo colocado. Então está com contrato emergencial ainda. Se revogar e publicar a revogação tem que republicar o resultado do edital. Aí é nossa, p*. Mesquita, Queimados, Botafogo e Campos", acrescentou o operador.  Para os investigadores, o grupo criminoso de Mário Peixoto pagou propina para funcionário público estadual ainda não identificado para obter o ato administrativo de revogação da desqualificação da OS, publicado no dia 23 de março.  Três dias depois do telefonema, a OS Instituto Unir Saúde foi reclassificado, podendo voltar a fechar contratos com o poder público. Segundo o MPF, a decisão não teve qualquer justificativa técnica.  Nesta segunda-feira (18), o jornal O Globo revelou que o governador Wilson Witzel ignorou pareceres jurídicos contra a OS Unir. Segundo a reportagem, em janeiro, a comissão de acompanhamento e fiscalização dos contratos de gestão da Secretaria da Casa Civil encontrou "numerosas e consideráveis irregularidades na atuação da OS Unir, principalmente, em relação à transparência nas informações prestadas, que impossibilitam a análise da aplicação dos recursos obtidos.  Luiz Roberto Martins foi preso na última semana em sua casa, em Vassouras, no Sul do estado. No local, a Polícia Federal encontrou R$ 1,5 milhão em espécie. O que dizem os citados O governo do estado disse que todos os contratos celebrados com as empresas envolvidas nas denúncias estão sendo auditados pela Controladoria Geral do Estado, para verificar possíveis ilegalidades e danos aos cofres públicos.  O governo também informou que estão sendo feitos cruzamentos de contratos sociais das empresas para identificar conluios entre elas e os sócios, e que, enquanto durar a auditoria da controladoria, todos os pagamentos aos fornecedores fiscalizados estão suspensos e que esses contratos podem ser cancelados se forem encontradas irregularidades.  Ainda segundo o governo, Wilson Witzel desqualificou o Instituto Unir Saúde num despacho publicado em edição extra do diário oficial.  O advogado de Luiz Roberto Martins informou que só vai se manifestar depois de analisar todos  ...
# [[42, 7289, 4133, 8, 200, 5, 2770, 686, 8, 188, 8, 48, 549, 13, 761, 5, 39, 3, 1953, 16, 4134, 6, 870, 2505, 2506, 3, 284, 6, 873, 124, 4135, 983, 1242, 16, 3, 1350, 913, 1, 1081, 4136, 198, 718, 5281, 3, 284, 1536, 5, 7290, 265, 7291, 1535, 1672, 7292, 2773, 53, 3469, 4, 274, 1081, 2193, 3, 1350, 70, 2, 13, 7293, 5, 3, 274, 7294, 2, 1323, 1, 15, 324, 102, 7295, 10, 3, 1899, 2, 324, 102, 286, 1592, 48, 1058, 687, 664, 10, 2, 188, 1, 48, 56, 14, 90, 1, 1304, 4, 1465, 44, 41, 7296, 23, 14, 31, 58, 7, 1351, 1, 649, 39, 19, 2110, 8, 200, 7297, 2, 14, 5282, 20, 1, 77, 1752, 189, 7, 664, 1, 7298, 1, 1593, 12, 4137, 49, 1, 86, 10, 2, 130, 107, 4, 3, 93, 157, 514, 3, 274, 1081, 2193, 4, 78, 1350, 913, 198, 718, 2933, 1166, 852, 12, 131, 826, 26, 14, 7299, 3470, 8, 14, 4, 5283, 7300, 2194, 7301, 10, 420, 1082, 5284, 5285, 7302, 2, 1242, 7, 463, 5, 2770, 1081, 2193, 26, 5286, 29, 7303, 7, 2388, 5287, 7304, 10, 1748, 8, 391, 11, 61, 360, 1, 630, 233, 553, 198, 718, 1142, 2366, 2, 15, 237, 335, 4138, 8, 4139, 39, 3, 1350, 913, 1, 1081, 4136, 3, 274, 323, 7305, 1191, 10, 3, 284, 4, 5, 40, 4140, 2507, 88, 4138, 1, 15, 237, 4141, 7306, 3, 1081, 5, 21, 40, 5, 7307, 803, 10, 3, 1899, 32, 17, 2191, 2360, 28, 137, 2507, 74, 1, 13, 326, 7308, 50, 3, 1350, 9, 15, 237, 335, 65, 15, 7309, 12, 5288, 198, 718, 1142, 183, 2, 2508, 78, 4142, 10, 3, 476, 8, 1592, 9, 1014, 30, 1593, 12, 4137, 1466, 314, 1, 234, 2195, 17, 170, 39, 7310, 179, 46, 10, 1467, 459, 2360, 25, 7311, 4, 5289, 2, 4143, 38, 5, 7312, 3, 422, 6, 7313, 675, 16, 1954, 7314, 7315, 7316, 4144, 4, 7317, 928, 3, 7318, 9, 14, 7319, 3, 166, 2505, 1, 1081, 2193, 5290, 7320, 9, 1243, 157, 204, 49, 17, 1541, 9, 1120, 3, 2196, 4145, 1, 4143, 8, 7321, 8, 7322, 1753, 11, 61, 1151, 1, 764, 159, 97, 126, 6, 7323, 2, 14, 286, 1592, 48, 21, 7324, 4146, 1232, 2, 1955, 664, 10, 3, 256, 969, 39, 3, 7325, 2, 313, 17, 176, 265, 7326, 7327, 47, 66, 253, 3, 559, 3, 1009, 2173, 5, 3, 284, 983, 1242, 7328, 3954, 7329, 87, 2, 14, 4139, 39, 2, 3471, 7, 434, 2, 2197, 1, 1037, 4, 1456, 22, 664, 1, 306, 8, 188, 8, 169, 489, 2509, 7330, 4, 7331, 1594, 12, 1698, 8, 14, 7332, 2934, 7, 195, 29, 1693, 51, 258, 7333, 5, 7334, 2, 1015, 8, 807, 22, 244, 7335, 198, 718, 1142, 21, 3472, 12, 341, 131, 7, 67, 513, 7, 7336, 11, 300, 6, 674, 11, 944, 2, 130, 107, 2509, 77, 1160, 610, 7, 7337, 3, 5, 982, 14, 3295, 3, 63, 6, 58, 50, 5, 111, 14, 664, 7338, 10, 19, 371, 4147, 51, 1119, 68, 146, 7339, 35, 2935, 709, 6, 711, 9, 1209, 1468, 7340, 4, 2923, 96, 4148, 2936, 3, 63, 33, 231, 5, 68, 146, 988, 4149, 1, 664, 490, 30, 371, 9, 609, 7341, 56, 480, 4, 14, 7342, 4, 110, 181, 5291, 2, 5292, 8, 7343, 111, 14, 2937, 96, 3473, 7344, 68, 7345, 4, 5, 304, 664, 190, 41, 7346, 25, 1407, 5293, 5294, 49, 39, 3, 636, 983, 1242, 7347, 3, 286, 1592, 48, 744, 5295, 1753, 7, 1220, 4150, 6, 1066, 3474, 3, 406, 1, 198, 718, 1142, 231, 5, 108, 85, 25, 2474, 126, 1, 2510, 111, 14, 5296, 6, 2511, 43]]
# (1, 600)
# (1, 600)
# Input: <start>  escutas telefônicas da operação que prendeu membros da secretaria da saúde mostram um homem que segundo o mp é integrante do esquema criminoso citando o governador do rio. quem menciona wilson witzel é o operador financeiro de mário peixoto, luiz roberto martins. o governador nega que cometeu qualquer ilegalidade. lava jato prende ex-deputado paulo melo e empresário mário peixoto o operador diz a um interlocutor que o empresário negociou a liberação de uma organização social (os) com o governador. a organização social instituto unir saúde fechou vários contratos com a secretaria de saúde entre os anos de 2018 e 2019 até ser desqualificada como os pelo estado em outubro de 2019.  segundo as investigações da operação favorito, a os movimentou mais de r$ 180 milhões em contratos de gestões de upas na baixada. ainda de acordo com a polícia federal e o ministério público federal, o empresário mário peixoto e seu operador financeiro luiz roberto martins, ambos presos na semana passada, são os verdadeiros donos da os e efetivamente promoveram negociação espúria com funcionários públicos estaduais. supostas citações a witzel em investigação que prendeu mário peixoto são enviadas à pgr em ligação telefônica interceptada com autorização da justiça no dia 20 de março deste ano, luiz roberto martins anuncia a uma outra pessoa reclassificação da unir. segundo o operador financeiro de mário peixoto, o empresário teria acertado diretamente com o governador e que ele estaria comprando essa reclassificação de uma outra pessoa.  "diz o mário que foi ele que acertou junto com o governador. mas não publicou ainda. eu estava comprando isso de um outro cara", disse o operador para uma outra pessoa durante uma ligação.  na conversa, luiz roberto martins chegou a mostrar seu entusiasmo com o retorno da unir para administração das upas na baixada.  "as quatro de nova iguaçu não têm segundo colocado. então está com contrato emergencial ainda. se revogar e publicar a revogação tem que republicar o resultado do edital. aí é nossa, p*. mesquita, queimados, botafogo e campos", acrescentou o operador.  para os investigadores, o grupo criminoso de mário peixoto pagou propina para funcionário público estadual ainda não identificado para obter o ato administrativo de revogação da desqualificação da os, publicado no dia 23 de março.  três dias depois do telefonema, a os instituto unir saúde foi reclassificado, podendo voltar a fechar contratos com o poder público. segundo o mpf, a decisão não teve qualquer justificativa técnica.  nesta segunda-feira (18), o jornal o globo revelou que o governador wilson witzel ignorou pareceres jurídicos contra a os unir. segundo a reportagem, em janeiro, a comissão de acompanhamento e fiscalização dos contratos de gestão da secretaria da casa civil encontrou "numerosas e consideráveis irregularidades na atuação da os unir, principalmente, em relação à transparência nas informações prestadas, que impossibilitam a análise da aplicação dos recursos obtidos.  luiz roberto martins foi preso na última semana em sua casa, em vassouras, no sul do estado. no local, a polícia federal encontrou r$ 1,5 milhão em espécie. o que dizem os citados o governo do estado disse que todos os contratos celebrados com as empresas envolvidas nas denúncias estão sendo auditados pela controladoria geral do estado, para verificar possíveis ilegalidades e danos aos cofres públicos.  o governo também informou que estão sendo feitos cruzamentos de contratos sociais das empresas para identificar conluios entre elas e os sócios, e que, enquanto durar a auditoria da controladoria, todos os pagamentos aos fornecedores fiscalizados estão suspensos e que esses contratos podem ser cancelados se forem encontradas irregularidades.  ainda segundo o governo, wilson witzel desqualificou o instituto unir saúde num despacho publicado em edição extra do diário oficial.  o advogado de luiz roberto martins informou que só vai se manifestar depois de analisar ...
# Predicted translation: operador de empresário preso cita negociação com witzel, mostra escuta <end>
