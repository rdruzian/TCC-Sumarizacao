# %%
import matplotlib.pyplot as plt
import numpy as np

fc = 1 # corte

tam = np.linspace(0, 100, 1000)
g1 = []
g2 = []
g3 = []
g4 = []
g5 = []
x = []

for x in range(len(tam)):
  g1.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*1) ) ) ))
  g2.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*2) ) ) ))
  g3.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*3) ) ) ))
  g4.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*4) ) ) ))
  g5.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*5) ) ) ))
  x.append(np.log10(tam[x]))

plt.plot(xlog, g1)
plt.plot(xlog, g2)
plt.plot(xlog, g3)
plt.plot(xlog, g4)
plt.plot(xlog, g5)
plt.ylim(bottom = -100)
plt.grid()
plt.show()
# Out:
# C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: divide by zero encountered in log10

# %%
import matplotlib.pyplot as plt
import numpy as np

fc = 3 # corte

tam = np.linspace(0, 100, 1000)
g1 = []
g2 = []
g3 = []
g4 = []
g5 = []
x = []

for x in range(len(tam)):
  g1.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*1) ) ) ))
  g2.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*2) ) ) ))
  g3.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*3) ) ) ))
  g4.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*4) ) ) ))
  g5.append(20*np.log10( 1/( np.sqrt( 1 + (tam[x] / fc)**(2*5) ) ) ))
  x.append(np.log10(tam[x]))

plt.plot(xlog, g1)
plt.plot(xlog, g2)
plt.plot(xlog, g3)
plt.plot(xlog, g4)
plt.plot(xlog, g5)
plt.ylim(bottom = -100)
plt.grid()
plt.show()
# Out:
# C:\Users\renat\Anaconda3\envs\TCC\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: divide by zero encountered in log10
